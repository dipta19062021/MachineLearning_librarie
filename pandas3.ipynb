# %%
import pandas as pd

# %%
help(pd.csv_read)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 help(pd.csv_read)
#
# File ~\anaconda3\lib\site-packages\pandas\__init__.py:264, in __getattr__(name)
#     260     from pandas.core.arrays.sparse import SparseArray as _SparseArray
#     262     return _SparseArray
# --> 264 raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#
# AttributeError: module 'pandas' has no attribute 'csv_read'

# %%
imhelp(pd.read_csv)
# Out:
# Help on function read_csv in module pandas.io.parsers.readers:
#
# ...

# %%
pd.read_csv('D:\\ml\\datasets\\health care diabetes.csv')
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
pd.read_csv('D:\\ml\\datasets\\company name.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 pd.read_csv('D:\\ml\\datasets\\company name.csv')
#
# NameError: name 'pd' is not defined

# %%
pd.read_csv('D:\\ml\\datasets\\company name.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 pd.read_csv('D:\\ml\\datasets\\company name.csv')
#
# NameError: name 'pd' is not defined

# %%
pd.read_csv('D:\\ml\\datasets\\company name.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 pd.read_csv('D:\\ml\\datasets\\company name.csv')
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd

# %%
pd.read_csv('D:\\ml\\datasets\\company name.csv')
# Out:
#    company name  Unnamed: 1
# 0           tcs         NaN
# 1     cognizant         NaN
# 2           IBM         NaN
# 3        Amazon         NaN
# 4      Flipkart         NaN
# 5      Facebook         NaN
# 6        Google         NaN
# 7       Infosis         NaN
# 8         Wipro         NaN
# 9           Ola         NaN
# 10          OYO         NaN
# 11        Adobe         NaN
# 12      Open AI         NaN
# 13     Microsft         NaN

# %%
import os

# %%
print(os.getcwd())
# Out:
# C:\Users\ADMIN\pandas tutorial

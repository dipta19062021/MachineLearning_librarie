# %%
import pandas as pd

# %%
df=pd.read_csv('D:\\ml\\datasets\\corporate.csv')
df
# Out:
#    ID         Name    Companies      Profit Growth
# 0   1         lisa  IT Services     5634256    20%
# 1   2          NaN      Finance   324543279    12%
# 2   3  corgrejohan       Health  1234432987    58%
# 3   4          NaN  IT Services  5463452876    60%
# 4   5         Mark          NaN     5678337    NaN

# %%
df.replaceace()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df.replaceace()
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'replaceace'

# %%
df.replace(to_replace='IT Services', value='Space startup')
# Out:
#    ID         Name      Companies      Profit Growth
# 0   1         lisa  Space startup     5634256    20%
# 1   2          NaN        Finance   324543279    12%
# 2   3  corgrejohan         Health  1234432987    58%
# 3   4          NaN  Space startup  5463452876    60%
# 4   5         Mark            NaN     5678337    NaN

# %%
df.replace('Health','Space startup')
# Out:
#    ID         Name      Companies      Profit Growth
# 0   1         lisa    IT Services     5634256    20%
# 1   2          NaN        Finance   324543279    12%
# 2   3  corgrejohan  Space startup  1234432987    58%
# 3   4          NaN    IT Services  5463452876    60%
# 4   5         Mark            NaN     5678337    NaN

# %%
df.replace(60%,30%)
# Out:
#   Cell In[9], line 1
#     df.replace(60%,30%)
#                   ^
# SyntaxError: invalid syntax

# %%
df.replace(60,30)
# Out:
#    ID         Name    Companies      Profit Growth
# 0   1         lisa  IT Services     5634256    20%
# 1   2          NaN      Finance   324543279    12%
# 2   3  corgrejohan       Health  1234432987    58%
# 3   4          NaN  IT Services  5463452876    60%
# 4   5         Mark          NaN     5678337    NaN

# %%
df.replace(2,5)
# Out:
#    ID         Name    Companies      Profit Growth
# 0   1         lisa  IT Services     5634256    20%
# 1   5          NaN      Finance   324543279    12%
# 2   3  corgrejohan       Health  1234432987    58%
# 3   4          NaN  IT Services  5463452876    60%
# 4   5         Mark          NaN     5678337    NaN

# %%
df.replace([1,2,3,4],[11,22,33,44])
# Out:
#    ID         Name    Companies      Profit Growth
# 0  11         lisa  IT Services     5634256    20%
# 1  22          NaN      Finance   324543279    12%
# 2  33  corgrejohan       Health  1234432987    58%
# 3  44          NaN  IT Services  5463452876    60%
# 4   5         Mark          NaN     5678337    NaN

# %%
df.replace({'Profit':5634256}, 'none')
# Out:
#    ID         Name    Companies      Profit Growth
# 0   1         lisa  IT Services        none    20%
# 1   2          NaN      Finance   324543279    12%
# 2   3  corgrejohan       Health  1234432987    58%
# 3   4          NaN  IT Services  5463452876    60%
# 4   5         Mark          NaN     5678337    NaN

# %%
df.replace({'Profit':5634256,'Name':'Mark'}, 'none')
# Out:
#    ID         Name    Companies      Profit Growth
# 0   1         lisa  IT Services        none    20%
# 1   2          NaN      Finance   324543279    12%
# 2   3  corgrejohan       Health  1234432987    58%
# 3   4          NaN  IT Services  5463452876    60%
# 4   5         none          NaN     5678337    NaN

# %%
df.replace('[A-Za-z]',0,regex=True) #replaces all string values into 0
# Out:
#    ID  Name  Companies      Profit Growth
# 0   1   0.0        0.0     5634256    20%
# 1   2   NaN        0.0   324543279    12%
# 2   3   0.0        0.0  1234432987    58%
# 3   4   NaN        0.0  5463452876    60%
# 4   5   0.0        NaN     5678337    NaN

# %%
df.replace('[A-Za-z]',0,regex=False)
# Out:
#    ID         Name    Companies      Profit Growth
# 0   1         lisa  IT Services     5634256    20%
# 1   2          NaN      Finance   324543279    12%
# 2   3  corgrejohan       Health  1234432987    58%
# 3   4          NaN  IT Services  5463452876    60%
# 4   5         Mark          NaN     5678337    NaN

# %%
df.replace({'Companies':'[A-Za-z]'},0,regex=True)
# Out:
#    ID         Name  Companies      Profit Growth
# 0   1         lisa        0.0     5634256    20%
# 1   2          NaN        0.0   324543279    12%
# 2   3  corgrejohan        0.0  1234432987    58%
# 3   4          NaN        0.0  5463452876    60%
# 4   5         Mark        NaN     5678337    NaN

# %%
df.replace('Health',method='ffill')
# Out:
#    ID         Name    Companies      Profit Growth
# 0   1         lisa  IT Services     5634256    20%
# 1   2          NaN      Finance   324543279    12%
# 2   3  corgrejohan      Finance  1234432987    58%
# 3   4          NaN  IT Services  5463452876    60%
# 4   5         Mark          NaN     5678337    NaN

# %%
df.replace('Health',method='bfill')
# Out:
#    ID         Name    Companies      Profit Growth
# 0   1         lisa  IT Services     5634256    20%
# 1   2          NaN      Finance   324543279    12%
# 2   3  corgrejohan  IT Services  1234432987    58%
# 3   4          NaN  IT Services  5463452876    60%
# 4   5         Mark          NaN     5678337    NaN

# %%
df.replace(0,method='bfill',limit=1)
# Out:
#    ID         Name    Companies      Profit Growth
# 0   1         lisa  IT Services     5634256    20%
# 1   2          NaN      Finance   324543279    12%
# 2   3  corgrejohan       Health  1234432987    58%
# 3   4          NaN  IT Services  5463452876    60%
# 4   5         Mark          NaN     5678337    NaN

# %%
df=pd.read_csv('D:\\ml\\datasets\\corporate.csv')
df
# Out:
#    ID         Name    Companies      Profit Growth
# 0   1         lisa  IT Services     5634256    20%
# 1   2          NaN      Finance   324543279    12%
# 2   3  corgrejohan       Health           0    58%
# 3   4          NaN  IT Services  5463452876    60%
# 4   5         Mark          NaN     5678337    NaN
# 5   6          NaN          NaN           0    NaN

# %%
df=pd.read_csv('D:\\ml\\datasets\\corporate.csv')
df
# Out:
#    ID         Name    Companies     Profit Growth
# 0   1         lisa  IT Services    5634256    20%
# 1   2          NaN      Finance  324543279    12%
# 2   3  corgrejohan       Health          0    58%
# 3   4          NaN  IT Services          0    60%
# 4   5         Mark          NaN    5678337    NaN
# 5   6          NaN          NaN          0    NaN

# %%
df.replace(0,method='bfill',limit=1)
# Out:
#    ID         Name    Companies     Profit Growth
# 0   1         lisa  IT Services    5634256    20%
# 1   2          NaN      Finance  324543279    12%
# 2   3  corgrejohan       Health          0    58%
# 3   4          NaN  IT Services    5678337    60%
# 4   5         Mark          NaN    5678337    NaN
# 5   6          NaN          NaN          0    NaN

# %%
df.replace(0,105,inplace=True)

# %%
df.replace(0,105,inplace=True)
df
# Out:
#    ID         Name    Companies     Profit Growth
# 0   1         lisa  IT Services    5634256    20%
# 1   2          NaN      Finance  324543279    12%
# 2   3  corgrejohan       Health        105    58%
# 3   4          NaN  IT Services        105    60%
# 4   5         Mark          NaN    5678337    NaN
# 5   6          NaN          NaN        105    NaN

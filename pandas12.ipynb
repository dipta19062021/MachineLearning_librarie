# %% [markdown]
# # Pandas interpolate

# %%
import pandas as pd

# %%
df=pd.read_csv('D:\\ml\\datasets\\health care diabetes.csv')
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148            NaN             29       94  33.6
# 1              1       85            NaN             39       87  26.6
# 2              8      183            NaN             43       94  23.3
# 3              1       89           66.0             23       94  28.1
# 4              0      137           40.0             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101           76.0             48      180  32.9
# 764            2      122           70.0             27        0  36.8
# 765            5      121           72.0             23      112  26.2
# 766            1      126           60.0              0        0  30.1
# 767            1       93           70.0             31        0  30.4
#
#      DiabetesPedigreeFunction   Age  Outcome
# 0                       0.627  21.0        1
# ...

# %%
df.interpolate()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148            NaN             29       94  33.6
# 1              1       85            NaN             39       87  26.6
# 2              8      183            NaN             43       94  23.3
# 3              1       89           66.0             23       94  28.1
# 4              0      137           40.0             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101           76.0             48      180  32.9
# 764            2      122           70.0             27        0  36.8
# 765            5      121           72.0             23      112  26.2
# 766            1      126           60.0              0        0  30.1
# 767            1       93           70.0             31        0  30.4
#
#      DiabetesPedigreeFunction   Age  Outcome
# 0                       0.627  21.0        1
# ...

# %%
df.interpolate(method='linear')
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148            NaN             29       94  33.6
# 1              1       85            NaN             39       87  26.6
# 2              8      183            NaN             43       94  23.3
# 3              1       89           66.0             23       94  28.1
# 4              0      137           40.0             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101           76.0             48      180  32.9
# 764            2      122           70.0             27        0  36.8
# 765            5      121           72.0             23      112  26.2
# 766            1      126           60.0              0        0  30.1
# 767            1       93           70.0             31        0  30.4
#
#      DiabetesPedigreeFunction   Age  Outcome
# 0                       0.627  21.0        1
# ...

# %%
df.interpolate(method='index')
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148            NaN             29       94  33.6
# 1              1       85            NaN             39       87  26.6
# 2              8      183            NaN             43       94  23.3
# 3              1       89           66.0             23       94  28.1
# 4              0      137           40.0             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101           76.0             48      180  32.9
# 764            2      122           70.0             27        0  36.8
# 765            5      121           72.0             23      112  26.2
# 766            1      126           60.0              0        0  30.1
# 767            1       93           70.0             31        0  30.4
#
#      DiabetesPedigreeFunction   Age  Outcome
# 0                       0.627  21.0        1
# ...

# %%
df=pd.read_csv('D:\\ml\\datasets\\health care diabetes.csv')
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148            NaN             29       94  33.6
# 1              1       85            NaN             39       87  26.6
# 2              8      183            NaN             43       94  23.3
# 3              1       89           66.0             23       94  28.1
# 4              0      137           40.0             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101           76.0             48      180  32.9
# 764            2      122           70.0             27        0  36.8
# 765            5      121           72.0             23      112  26.2
# 766            1      126           60.0              0        0  30.1
# 767            1       93           70.0             31        0  30.4
#
#      DiabetesPedigreeFunction   Age  Outcome        Date
# 0                       0.627  21.0        1  01-11-2002
# ...

# %%
type(df.Date[0])
# Out:
# str

# %%
df=pd.read_csv('D:\\ml\\datasets\\health care diabetes.csv', parse_dates=['Date'])
df
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_16520\1382007687.py:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df=pd.read_csv('D:\\ml\\datasets\\health care diabetes.csv', parse_dates=['Date'])
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148            NaN             29       94  33.6
# 1              1       85            NaN             39       87  26.6
# 2              8      183            NaN             43       94  23.3
# 3              1       89           66.0             23       94  28.1
# 4              0      137           40.0             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101           76.0             48      180  32.9
# ...

# %%
type(df.Date[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df=pd.read_csv('D:\\ml\\datasets\\health care diabetes.csv', parse_dates=['Date'], index_col=['Date'])
df
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_16520\2623638547.py:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df=pd.read_csv('D:\\ml\\datasets\\health care diabetes.csv', parse_dates=['Date'], index_col=['Date'])
#             Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# Date
# 2002-01-11            6      148            NaN             29       94  33.6
# 2002-02-11            1       85            NaN             39       87  26.6
# 2002-03-11            8      183            NaN             43       94  23.3
# 2002-04-11            1       89           66.0             23       94  28.1
# 2002-05-11            0      137           40.0             35      168  43.1
# ...                 ...      ...            ...            ...      ...   ...
# ...

# %%
type(df.Date[0])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 type(df.Date[0])
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'Date'

# %%
df.interpolate(method='time')
# Out:
#             Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# Date
# 2002-01-11            6      148            NaN             29       94  33.6
# 2002-02-11            1       85            NaN             39       87  26.6
# 2002-03-11            8      183            NaN             43       94  23.3
# 2002-04-11            1       89           66.0             23       94  28.1
# 2002-05-11            0      137           40.0             35      168  43.1
# ...                 ...      ...            ...            ...      ...   ...
# 2004-03-12           10      101           76.0             48      180  32.9
# 2004-04-12            2      122           70.0             27        0  36.8
# 2004-05-12            5      121           72.0             23      112  26.2
# 2004-06-12            1      126           60.0              0        0  30.1
# 2004-07-12            1       93           70.0             31        0  30.4
#
# ...

# %%
df.interpolate(method='time')
# Out:
#             Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# Date
# 2002-01-11            6      148            NaN             29       94  33.6
# 2002-02-11            1       85            NaN             39       87  26.6
# 2002-03-11            8      183            NaN             43       94  23.3
# 2002-04-11            1       89           66.0             23       94  28.1
# 2002-05-11            0      137           40.0             35      168  43.1
# ...                 ...      ...            ...            ...      ...   ...
# 2004-03-12           10      101           76.0             48      180  32.9
# 2004-04-12            2      122           70.0             27        0  36.8
# 2004-05-12            5      121           72.0             23      112  26.2
# 2004-06-12            1      126           60.0              0        0  30.1
# 2004-07-12            1       93           70.0             31        0  30.4
#
# ...

# %%
df.interpolate(method='nearest')
# Out:
#             Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# Date
# 2002-01-11            6      148            NaN             29       94  33.6
# 2002-02-11            1       85            NaN             39       87  26.6
# 2002-03-11            8      183            NaN             43       94  23.3
# 2002-04-11            1       89           66.0             23       94  28.1
# 2002-05-11            0      137           40.0             35      168  43.1
# ...                 ...      ...            ...            ...      ...   ...
# 2004-03-12           10      101           76.0             48      180  32.9
# 2004-04-12            2      122           70.0             27        0  36.8
# 2004-05-12            5      121           72.0             23      112  26.2
# 2004-06-12            1      126           60.0              0        0  30.1
# 2004-07-12            1       93           70.0             31        0  30.4
#
# ...

# %%
df.interpolate(method='polynomial', order=1)
# Out:
#             Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# Date
# 2002-01-11            6      148            NaN             29       94  33.6
# 2002-02-11            1       85            NaN             39       87  26.6
# 2002-03-11            8      183            NaN             43       94  23.3
# 2002-04-11            1       89           66.0             23       94  28.1
# 2002-05-11            0      137           40.0             35      168  43.1
# ...                 ...      ...            ...            ...      ...   ...
# 2004-03-12           10      101           76.0             48      180  32.9
# 2004-04-12            2      122           70.0             27        0  36.8
# 2004-05-12            5      121           72.0             23      112  26.2
# 2004-06-12            1      126           60.0              0        0  30.1
# 2004-07-12            1       93           70.0             31        0  30.4
#
# ...

# %%
df.interpolate(method='spline', order=2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 df.interpolate(method='spline', order=2)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:11855, in DataFrame.interpolate(self, method, axis, limit, inplace, limit_direction, limit_area, downcast, **kwargs)
#   11843 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "method"])
#   11844 def interpolate(
#   11845     self: DataFrame,
# ...

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
df=pd.read_csv('D:\\ml\\datasets\\health care diabetes.csv')
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df=pd.read_csv('D:\\ml\\datasets\\health care diabetes.csv')
#       2 df
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd

# %%
df=pd.read_csv('D:\\ml\\datasets\\corporate.csv')
df
# Out:
#    ID         Name    Companies     Profit Growth
# 0   1         lisa  IT Services    5634256    20%
# 1   2          NaN      Finance  324543279    12%
# 2   3  corgrejohan       Health          0    58%
# 3   4          NaN  IT Services          0    60%
# 4   5         Mark          NaN    5678337    NaN
# 5   6          NaN          NaN          0    NaN

# %%
df.interpolate()
# Out:
#    ID         Name    Companies     Profit Growth
# 0   1         lisa  IT Services    5634256    20%
# 1   2          NaN      Finance  324543279    12%
# 2   3  corgrejohan       Health          0    58%
# 3   4          NaN  IT Services          0    60%
# 4   5         Mark          NaN    5678337    NaN
# 5   6          NaN          NaN          0    NaN

# %%
df.interpolate()
# Out:
#    ID         Name    Companies     Profit Growth
# 0   1         lisa  IT Services    5634256    20%
# 1   2          NaN      Finance  324543279    12%
# 2   3  corgrejohan       Health          0    58%
# 3   4          NaN  IT Services          0    60%
# 4   5         Mark          NaN    5678337    NaN
# 5   6          NaN          NaN          0    NaN

# %%
df.dtypes
# Out:
# ID            int64
# Name         object
# Companies    object
# Profit        int64
# Growth       object
# dtype: object

# %%
df.interpolate(limit=1)
# Out:
#    ID         Name    Companies     Profit Growth
# 0   1         lisa  IT Services    5634256    20%
# 1   2          NaN      Finance  324543279    12%
# 2   3  corgrejohan       Health          0    58%
# 3   4          NaN  IT Services          0    60%
# 4   5         Mark          NaN    5678337    NaN
# 5   6          NaN          NaN          0    NaN

# %%
df=pd.read_csv('D:\\ml\\datasets\\corporate.csv')
df
# Out:
#    ID  Name    Companies     Profit Growth
# 0   1  lisa  IT Services    5634256    20%
# 1   2   NaN      Finance  324543279    12%
# 2   3   NaN       Health          0    58%
# 3   4   NaN  IT Services          0    60%
# 4   5  Mark          NaN    5678337    NaN
# 5   6   NaN          NaN          0    NaN

# %%
df.interpolate()
# Out:
#    ID  Name    Companies     Profit Growth
# 0   1  lisa  IT Services    5634256    20%
# 1   2   NaN      Finance  324543279    12%
# 2   3   NaN       Health          0    58%
# 3   4   NaN  IT Services          0    60%
# 4   5  Mark          NaN    5678337    NaN
# 5   6   NaN          NaN          0    NaN

# %%
df.interpolate(limit=2)
# Out:
#    ID  Name    Companies     Profit Growth
# 0   1  lisa  IT Services    5634256    20%
# 1   2   NaN      Finance  324543279    12%
# 2   3   NaN       Health          0    58%
# 3   4   NaN  IT Services          0    60%
# 4   5  Mark          NaN    5678337    NaN
# 5   6   NaN          NaN          0    NaN

# %%
df.interpolate(limit=1, limit_direction='backward')
# Out:
#    ID  Name    Companies     Profit Growth
# 0   1  lisa  IT Services    5634256    20%
# 1   2   NaN      Finance  324543279    12%
# 2   3   NaN       Health          0    58%
# 3   4   NaN  IT Services          0    60%
# 4   5  Mark          NaN    5678337    NaN
# 5   6   NaN          NaN          0    NaN

# %%
df=pd.read_csv('D:\\ml\\datasets\\corporate.csv')
df
# Out:
#    ID   Name    Companies       Profit Growth
# 0   1   lisa  IT Services    5634256.0    20%
# 1   2   neha      Finance  324543279.0    12%
# 2   3  risav       Health          NaN    58%
# 3   4    doj  IT Services          NaN    60%
# 4   5   Mark          NaN    5678337.0    NaN
# 5   6    NaN          NaN          0.0    49%

# %%
df.interpolate(limit=2)
# Out:
#    ID   Name    Companies       Profit Growth
# 0   1   lisa  IT Services    5634256.0    20%
# 1   2   neha      Finance  324543279.0    12%
# 2   3  risav       Health  218254965.0    58%
# 3   4    doj  IT Services  111966651.0    60%
# 4   5   Mark          NaN    5678337.0    NaN
# 5   6    NaN          NaN          0.0    49%

# %%
df.interpolate()
# Out:
#    ID   Name    Companies       Profit Growth
# 0   1   lisa  IT Services    5634256.0    20%
# 1   2   neha      Finance  324543279.0    12%
# 2   3  risav       Health  218254965.0    58%
# 3   4    doj  IT Services  111966651.0    60%
# 4   5   Mark          NaN    5678337.0    NaN
# 5   6    NaN          NaN          0.0    49%

# %%
df.interpolate(limit=1)
# Out:
#    ID   Name    Companies       Profit Growth
# 0   1   lisa  IT Services    5634256.0    20%
# 1   2   neha      Finance  324543279.0    12%
# 2   3  risav       Health  218254965.0    58%
# 3   4    doj  IT Services          NaN    60%
# 4   5   Mark          NaN    5678337.0    NaN
# 5   6    NaN          NaN          0.0    49%

# %%
df=pd.read_csv('D:\\ml\\datasets\\corporate.csv')
df
# Out:
#    ID   Name    Companies       Profit Growth
# 0   1   lisa  IT Services    5634256.0    20%
# 1   2   neha      Finance  324543279.0    12%
# 2   3  risav       Health          NaN    58%
# 3   4    doj  IT Services          NaN    60%
# 4   5   Mark          NaN    5678337.0    NaN
# 5   6    NaN          NaN          NaN    49%

# %%
df.interpolate() #fills the blank value of table of only int64 data type
# Out:
#    ID   Name    Companies       Profit Growth
# 0   1   lisa  IT Services    5634256.0    20%
# 1   2   neha      Finance  324543279.0    12%
# 2   3  risav       Health  218254965.0    58%
# 3   4    doj  IT Services  111966651.0    60%
# 4   5   Mark          NaN    5678337.0    NaN
# 5   6    NaN          NaN    5678337.0    49%

# %%
df.interpolate(limit=1) #fills consecutive one of the blank values of table of only int64 data type
# Out:
#    ID   Name    Companies       Profit Growth
# 0   1   lisa  IT Services    5634256.0    20%
# 1   2   neha      Finance  324543279.0    12%
# 2   3  risav       Health  218254965.0    58%
# 3   4    doj  IT Services          NaN    60%
# 4   5   Mark          NaN    5678337.0    NaN
# 5   6    NaN          NaN    5678337.0    49%

# %%
import pandas as pd

# %%
df=pd.read_csv('D:\\ml\\datasets\\corporate.csv')
df
# Out:
#    ID   Name    Companies       Profit Growth
# 0   1   lisa  IT Services    5634256.0    20%
# 1   2   neha      Finance  324543279.0    12%
# 2   3  risav       Health          NaN    58%
# 3   4    doj  IT Services          NaN    60%
# 4   5   Mark          NaN    5678337.0    NaN
# 5   6    NaN          NaN          NaN    49%

# %%
df.interpolate(limit=1, limit_direction='backward') #filling blank values from the backward i.e taking last value present as reference and selecting a value nearest to it'
# Out:
#    ID   Name    Companies       Profit Growth
# 0   1   lisa  IT Services    5634256.0    20%
# 1   2   neha      Finance  324543279.0    12%
# 2   3  risav       Health          NaN    58%
# 3   4    doj  IT Services  111966651.0    60%
# 4   5   Mark          NaN    5678337.0    NaN
# 5   6    NaN          NaN          NaN    49%

# %%
import pandas as pd

# %%
df=pd.read_csv('D:\\ml\\datasets\\Population_Berlin.csv')
df
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 df=pd.read_csv('D:\\ml\\datasets\\Population_Berlin.csv')
#       2 df
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# ...

# %%
df=pd.read_csv('D:\\ml\\datasets\\corporate.csv')
df
# Out:
#    ID   Name    Companies       Profit Growth
# 0   1   lisa  IT Services    5634256.0    20%
# 1   2   neha      Finance  324543279.0    12%
# 2   3  risav       Health          NaN    58%
# 3   4    doj  IT Services          NaN    60%
# 4   5   Mark          NaN    5678337.0    NaN
# 5   6    NaN          NaN          NaN    49%

# %%
df.interpolate(limit_area= 'inside') #fills the previous null places with values according to the last filled values
# Out:
#    ID   Name    Companies       Profit Growth
# 0   1   lisa  IT Services    5634256.0    20%
# 1   2   neha      Finance  324543279.0    12%
# 2   3  risav       Health  218254965.0    58%
# 3   4    doj  IT Services  111966651.0    60%
# 4   5   Mark          NaN    5678337.0    NaN
# 5   6    NaN          NaN          NaN    49%

# %%
df.interpolate(limit_area= 'outside') #fills the next null places with values according to the last filled values
# Out:
#    ID   Name    Companies       Profit Growth
# 0   1   lisa  IT Services    5634256.0    20%
# 1   2   neha      Finance  324543279.0    12%
# 2   3  risav       Health          NaN    58%
# 3   4    doj  IT Services          NaN    60%
# 4   5   Mark          NaN    5678337.0    NaN
# 5   6    NaN          NaN    5678337.0    49%

# %%
df.interpolate(inplace=True) #fillup every  nan values and update the main dataset
df
# Out:
#    ID   Name    Companies       Profit Growth
# 0   1   lisa  IT Services    5634256.0    20%
# 1   2   neha      Finance  324543279.0    12%
# 2   3  risav       Health  218254965.0    58%
# 3   4    doj  IT Services  111966651.0    60%
# 4   5   Mark          NaN    5678337.0    NaN
# 5   6    NaN          NaN    5678337.0    49%

# %%
df
# Out:
#    ID   Name    Companies       Profit Growth
# 0   1   lisa  IT Services    5634256.0    20%
# 1   2   neha      Finance  324543279.0    12%
# 2   3  risav       Health  218254965.0    58%
# 3   4    doj  IT Services  111966651.0    60%
# 4   5   Mark          NaN    5678337.0    NaN
# 5   6    NaN          NaN    5678337.0    49%

# %% [markdown]
# # Handling missing values-3

# %%
import pandas as pd

# %%
pd.read_csv('D:\\ml\\datasets\\corporate.csv')
# Out:
#    ID         Name    Companies      Profit Growth
# 0   1         lisa  IT Services     5634256    20%
# 1   2       julius      Finance   324543279    12%
# 2   3  corgrejohan       Health  1234432987    58%
# 3   4          NaN  IT Services  5463452876  6000%
# 4   5         Mark          NaN     5678337    NaN

# %%
df=pd.read_csv('D:\\ml\\datasets\\corporate.csv')
df
# Out:
#    ID         Name    Companies      Profit Growth
# 0   1         lisa  IT Services     5634256    20%
# 1   2       julius      Finance   324543279    12%
# 2   3  corgrejohan       Health  1234432987    58%
# 3   4          NaN  IT Services  5463452876    60%
# 4   5         Mark          NaN     5678337    NaN

# %%
df.dropna()
# Out:
#    ID         Name    Companies      Profit Growth
# 0   1         lisa  IT Services     5634256    20%
# 1   2       julius      Finance   324543279    12%
# 2   3  corgrejohan       Health  1234432987    58%

# %%
df.dropna(axis=1)
# Out:
#    ID      Profit
# 0   1     5634256
# 1   2   324543279
# 2   3  1234432987
# 3   4  5463452876
# 4   5     5678337

# %%
df.dropna(how='any')
# Out:
#    ID         Name    Companies      Profit Growth
# 0   1         lisa  IT Services     5634256    20%
# 1   2       julius      Finance   324543279    12%
# 2   3  corgrejohan       Health  1234432987    58%

# %%
df.dropna(axis=1, how='any')
# Out:
#    ID      Profit
# 0   1     5634256
# 1   2   324543279
# 2   3  1234432987
# 3   4  5463452876
# 4   5     5678337

# %%
df.dropna(how='all')
# Out:
#    ID         Name    Companies      Profit Growth
# 0   1         lisa  IT Services     5634256    20%
# 1   2       julius      Finance   324543279    12%
# 2   3  corgrejohan       Health  1234432987    58%
# 3   4          NaN  IT Services  5463452876    60%
# 4   5         Mark          NaN     5678337    NaN

# %% [markdown]
# # DateTimeIndex function in pandas

# %%
import pandas as pd

# %%
df=pd.read_csv('D:\\ml\\datasets\\health care diabetes.csv')
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148            NaN             29       94  33.6
# 1              1       85            NaN             39       87  26.6
# 2              8      183            NaN             43       94  23.3
# 3              1       89           66.0             23       94  28.1
# 4              0      137           40.0             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101           76.0             48      180  32.9
# 764            2      122           70.0             27        0  36.8
# 765            5      121           72.0             23      112  26.2
# 766            1      126           60.0              0        0  30.1
# 767            1       93           70.0             31        0  30.4
#
#      DiabetesPedigreeFunction   Age  Outcome        Date
# 0                       0.627  21.0        1  01-11-2002
# ...

# %%
df.dtypes
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure               float64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                         float64
# Outcome                       int64
# Date                         object
# dtype: object

# %%
df=pd.read_csv('D:\\ml\\datasets\\health care diabetes.csv', parse_dates=['Date'])
df
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_3124\2812019739.py:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df=pd.read_csv('D:\\ml\\datasets\\health care diabetes.csv', parse_dates=['Date'])
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148            NaN             29       94  33.6
# 1              1       85            NaN             39       87  26.6
# 2              8      183            NaN             43       94  23.3
# 3              1       89           66.0             23       94  28.1
# 4              0      137           40.0             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101           76.0             48      180  32.9
# ...

# %%
df.dtypes
# Out:
# Pregnancies                          int64
# Glucose                              int64
# BloodPressure                      float64
# SkinThickness                        int64
# Insulin                              int64
# BMI                                float64
# DiabetesPedigreeFunction           float64
# Age                                float64
# Outcome                              int64
# Date                        datetime64[ns]
# dtype: object

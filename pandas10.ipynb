# %% [markdown]
# # Pandas fillna

# %%
import pandas as pd

# %%
df=pd.read_csv('D:\\ml\\datasets\\corporate.csv')
df
# Out:
#    ID         Name    Companies      Profit Growth
# 0   1         lisa  IT Services     5634256    20%
# 1   2       julius      Finance   324543279    12%
# 2   3  corgrejohan       Health  1234432987    58%
# 3   4          NaN  IT Services  5463452876    60%
# 4   5         Mark          NaN     5678337    NaN

# %%
df.fillna(0)
# Out:
#    ID         Name    Companies      Profit Growth
# 0   1         lisa  IT Services     5634256    20%
# 1   2       julius      Finance   324543279    12%
# 2   3  corgrejohan       Health  1234432987    58%
# 3   4            0  IT Services  5463452876    60%
# 4   5         Mark            0     5678337      0

# %%
df.fillna(2)
# Out:
#    ID         Name    Companies      Profit Growth
# 0   1         lisa  IT Services     5634256    20%
# 1   2       julius      Finance   324543279    12%
# 2   3  corgrejohan       Health  1234432987    58%
# 3   4            2  IT Services  5463452876    60%
# 4   5         Mark            2     5678337      2

# %%
df.fillna({'Name': 'none', 'Companies': 0 , 'Growth': 2})
# Out:
#    ID         Name    Companies      Profit Growth
# 0   1         lisa  IT Services     5634256    20%
# 1   2       julius      Finance   324543279    12%
# 2   3  corgrejohan       Health  1234432987    58%
# 3   4         none  IT Services  5463452876    60%
# 4   5         Mark            0     5678337      2

# %%
df.fillna(method='ffill')
# Out:
#    ID         Name    Companies      Profit Growth
# 0   1         lisa  IT Services     5634256    20%
# 1   2       julius      Finance   324543279    12%
# 2   3  corgrejohan       Health  1234432987    58%
# 3   4  corgrejohan  IT Services  5463452876    60%
# 4   5         Mark  IT Services     5678337    60%

# %%
df.fillna(method='pad')
# Out:
#    ID         Name    Companies      Profit Growth
# 0   1         lisa  IT Services     5634256    20%
# 1   2       julius      Finance   324543279    12%
# 2   3  corgrejohan       Health  1234432987    58%
# 3   4  corgrejohan  IT Services  5463452876    60%
# 4   5         Mark  IT Services     5678337    60%

# %%
df.fillna(method='bfill')
# Out:
#    ID         Name    Companies      Profit Growth
# 0   1         lisa  IT Services     5634256    20%
# 1   2       julius      Finance   324543279    12%
# 2   3  corgrejohan       Health  1234432987    58%
# 3   4         Mark  IT Services  5463452876    60%
# 4   5         Mark          NaN     5678337    NaN

# %%
df.fillna(method='ffill', axis=0)
# Out:
#    ID         Name    Companies      Profit Growth
# 0   1         lisa  IT Services     5634256    20%
# 1   2       julius      Finance   324543279    12%
# 2   3  corgrejohan       Health  1234432987    58%
# 3   4  corgrejohan  IT Services  5463452876    60%
# 4   5         Mark  IT Services     5678337    60%

# %%
df.fillna(method='ffill', axis=1)
# Out:
#   ID         Name    Companies      Profit   Growth
# 0  1         lisa  IT Services     5634256      20%
# 1  2       julius      Finance   324543279      12%
# 2  3  corgrejohan       Health  1234432987      58%
# 3  4            4  IT Services  5463452876      60%
# 4  5         Mark         Mark     5678337  5678337

# %%
df.fillna(method='bfill', axis=0)
# Out:
#    ID         Name    Companies      Profit Growth
# 0   1         lisa  IT Services     5634256    20%
# 1   2       julius      Finance   324543279    12%
# 2   3  corgrejohan       Health  1234432987    58%
# 3   4         Mark  IT Services  5463452876    60%
# 4   5         Mark          NaN     5678337    NaN

# %%
df.fillna(0,limit=1)
# Out:
#    ID         Name    Companies      Profit Growth
# 0   1         lisa  IT Services     5634256    20%
# 1   2       julius      Finance   324543279    12%
# 2   3  corgrejohan       Health  1234432987    58%
# 3   4            0  IT Services  5463452876    60%
# 4   5         Mark            0     5678337      0

# %%
df.fillna(0,limit=1)
# Out:
#    ID         Name    Companies      Profit Growth
# 0   1         lisa  IT Services     5634256    20%
# 1   2       julius      Finance   324543279    12%
# 2   3  corgrejohan       Health  1234432987    58%
# 3   4            0  IT Services  5463452876    60%
# 4   5         Mark            0     5678337      0

# %%
df=pd.read_csv('D:\\ml\\datasets\\corporate.csv')
df
# Out:
#    ID         Name    Companies      Profit Growth
# 0   1         lisa  IT Services     5634256    20%
# 1   2          NaN      Finance   324543279    12%
# 2   3  corgrejohan       Health  1234432987    58%
# 3   4          NaN  IT Services  5463452876    60%
# 4   5         Mark          NaN     5678337    NaN

# %%
df.fillna(0,limit=1)
# Out:
#    ID         Name    Companies      Profit Growth
# 0   1         lisa  IT Services     5634256    20%
# 1   2            0      Finance   324543279    12%
# 2   3  corgrejohan       Health  1234432987    58%
# 3   4          NaN  IT Services  5463452876    60%
# 4   5         Mark            0     5678337      0

# %%
df.fillna(0,limit=2)
# Out:
#    ID         Name    Companies      Profit Growth
# 0   1         lisa  IT Services     5634256    20%
# 1   2            0      Finance   324543279    12%
# 2   3  corgrejohan       Health  1234432987    58%
# 3   4            0  IT Services  5463452876    60%
# 4   5         Mark            0     5678337      0

# %%
df.fillna(method='ffill',limit=1)
# Out:
#    ID         Name    Companies      Profit Growth
# 0   1         lisa  IT Services     5634256    20%
# 1   2         lisa      Finance   324543279    12%
# 2   3  corgrejohan       Health  1234432987    58%
# 3   4  corgrejohan  IT Services  5463452876    60%
# 4   5         Mark  IT Services     5678337    60%

# %%
df.fillna(5,inplace=True)
df
# Out:
#    ID         Name    Companies      Profit Growth
# 0   1         lisa  IT Services     5634256    20%
# 1   2            5      Finance   324543279    12%
# 2   3  corgrejohan       Health  1234432987    58%
# 3   4            5  IT Services  5463452876    60%
# 4   5         Mark            5     5678337      5
